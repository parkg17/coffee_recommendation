# %%
# Library Declaration
import pandas as pd
import numpy as np
from operator import itemgetter

# %%
train_data = pd.read_excel(".\dataset.xlsx", engine = "openpyxl")
train_data = train_data.dropna(subset = ["ROAST_LEVEL"])
train_data.rename(columns = {'AGTRON':"BEFORE_AGTRON"}, inplace=True)
train_data["BEFORE_AGTRON"] = train_data["BEFORE_AGTRON"].str.split('/')
train_data.insert(4, "AFTER_AGTRON", train_data["BEFORE_AGTRON"].apply(itemgetter(1)).astype(int))
train_data["BEFORE_AGTRON"] = train_data["BEFORE_AGTRON"].apply(itemgetter(0)).astype(int)

grouped_train_data = train_data.groupby(['GROWING_REGION', 'TREE_VARIETY', 'ROAST_LEVEL']).mean().fillna(5.0)
grouped_train_data
# Out:
#                                                          BEFORE_AGTRON  \
# GROWING_REGION       TREE_VARIETY          ROAST_LEVEL
# region_africa_arabia tree_variety_bourbon  Light             64.375000
#                                            Medium            49.333333
#                                            Medium-Dark       44.000000
#                                            Medium-Light      56.740741
#                      tree_variety_catuai   Medium-Light      56.666667
# ...                                                                ...
# region_south_america tree_variety_pacamara Medium-Light      58.000000
#                      tree_variety_robusta  Medium-Light      54.000000
#                      tree_variety_typica   Light             59.500000
#                                            Medium            49.500000
#                                            Medium-Light      56.240000
#
#                                                          AFTER_AGTRON  \
# GROWING_REGION       TREE_VARIETY          ROAST_LEVEL
# region_africa_arabia tree_variety_bourbon  Light            82.125000
#                                            Medium           65.166667
#                                            Medium-Dark      52.666667
#                                            Medium-Light     75.518519
#                      tree_variety_catuai   Medium-Light     72.666667
# ...                                                               ...
# region_south_america tree_variety_pacamara Medium-Light     78.000000
#                      tree_variety_robusta  Medium-Light     72.000000
#                      tree_variety_typica   Light            77.000000
#                                            Medium           66.000000
#                                            Medium-Light     74.960000
#
#                                                             AROMA  \
# GROWING_REGION       TREE_VARIETY          ROAST_LEVEL
# region_africa_arabia tree_variety_bourbon  Light         9.000000
#                                            Medium        8.666667
#                                            Medium-Dark   8.333333
#                                            Medium-Light  8.759259
#                      tree_variety_catuai   Medium-Light  8.333333
# ...                                                           ...
# region_south_america tree_variety_pacamara Medium-Light  8.666667
#                      tree_variety_robusta  Medium-Light  9.000000
#                      tree_variety_typica   Light         9.000000
#                                            Medium        8.500000
#                                            Medium-Light  8.920000
#
#                                                          ACIDITY/STRUCTURE  \
# GROWING_REGION       TREE_VARIETY          ROAST_LEVEL
# region_africa_arabia tree_variety_bourbon  Light                  8.250000
#                                            Medium                 8.500000
#                                            Medium-Dark            5.000000
#                                            Medium-Light           8.375000
#                      tree_variety_catuai   Medium-Light           8.000000
# ...                                                                    ...
# region_south_america tree_variety_pacamara Medium-Light           8.500000
#                      tree_variety_robusta  Medium-Light           5.000000
#                      tree_variety_typica   Light                  8.500000
#                                            Medium                 8.000000
#                                            Medium-Light           8.347826
#
#                                                              BODY    FLAVOR  \
# GROWING_REGION       TREE_VARIETY          ROAST_LEVEL
# region_africa_arabia tree_variety_bourbon  Light         8.750000  9.000000
#                                            Medium        8.333333  9.000000
#                                            Medium-Dark   8.000000  8.333333
#                                            Medium-Light  8.611111  8.925926
#                      tree_variety_catuai   Medium-Light  8.333333  8.666667
# ...                                                           ...       ...
# region_south_america tree_variety_pacamara Medium-Light  9.000000  9.000000
#                      tree_variety_robusta  Medium-Light  9.000000  9.000000
#                      tree_variety_typica   Light         9.000000  9.000000
#                                            Medium        8.500000  9.000000
#                                            Medium-Light  8.520000  9.000000
#
#                                                          AFTERTASTE
# GROWING_REGION       TREE_VARIETY          ROAST_LEVEL
# region_africa_arabia tree_variety_bourbon  Light           8.000000
#                                            Medium          8.333333
#                                            Medium-Dark     8.000000
#                                            Medium-Light    8.000000
#                      tree_variety_catuai   Medium-Light    8.000000
# ...                                                             ...
# region_south_america tree_variety_pacamara Medium-Light    8.333333
#                      tree_variety_robusta  Medium-Light    9.000000
#                      tree_variety_typica   Light           8.000000
#                                            Medium          8.000000
#                                            Medium-Light    7.960000
#
# [113 rows x 7 columns]

# %%
group_train_data = grouped_train_data.reset_index()
group_train_data["COFFEE BEAN"] = group_train_data["GROWING_REGION"] + " " + group_train_data["TREE_VARIETY"] + \
                                " " + group_train_data["ROAST_LEVEL"]

# Column Relocation
col1 = group_train_data.columns[-1:].to_list()
col2 = group_train_data.columns[:-1].to_list()
new_col = col1 + col2
group_train_data = group_train_data[new_col]
group_train_data = group_train_data.drop(["GROWING_REGION", "TREE_VARIETY", "ROAST_LEVEL"], axis=1)
group_train_data["AROMA"] = group_train_data["AROMA"] * 10.0
group_train_data["ACIDITY/STRUCTURE"] = group_train_data["ACIDITY/STRUCTURE"] * 10.0
group_train_data["BODY"] = group_train_data["BODY"] * 10.0
group_train_data["FLAVOR"] = group_train_data["FLAVOR"] * 10.0
group_train_data["AFTERTASTE"] = group_train_data["AFTERTASTE"] * 10.0

pd.set_option('display.max_rows', 20)
group_train_data
# Out:
#                                            COFFEE BEAN  BEFORE_AGTRON  \
# 0      region_africa_arabia tree_variety_bourbon Light      64.375000
# 1     region_africa_arabia tree_variety_bourbon Medium      49.333333
# 2    region_africa_arabia tree_variety_bourbon Medi...      44.000000
# 3    region_africa_arabia tree_variety_bourbon Medi...      56.740741
# 4    region_africa_arabia tree_variety_catuai Mediu...      56.666667
# ..                                                 ...            ...
# 108  region_south_america tree_variety_pacamara Med...      58.000000
# 109  region_south_america tree_variety_robusta Medi...      54.000000
# 110     region_south_america tree_variety_typica Light      59.500000
# 111    region_south_america tree_variety_typica Medium      49.500000
# 112  region_south_america tree_variety_typica Mediu...      56.240000
#
#      AFTER_AGTRON      AROMA  ACIDITY/STRUCTURE       BODY     FLAVOR  \
# 0       82.125000  90.000000          82.500000  87.500000  90.000000
# 1       65.166667  86.666667          85.000000  83.333333  90.000000
# 2       52.666667  83.333333          50.000000  80.000000  83.333333
# 3       75.518519  87.592593          83.750000  86.111111  89.259259
# 4       72.666667  83.333333          80.000000  83.333333  86.666667
# ..            ...        ...                ...        ...        ...
# 108     78.000000  86.666667          85.000000  90.000000  90.000000
# 109     72.000000  90.000000          50.000000  90.000000  90.000000
# 110     77.000000  90.000000          85.000000  90.000000  90.000000
# 111     66.000000  85.000000          80.000000  85.000000  90.000000
# 112     74.960000  89.200000          83.478261  85.200000  90.000000
#
#      AFTERTASTE
# 0     80.000000
# 1     83.333333
# 2     80.000000
# 3     80.000000
# 4     80.000000
# ..          ...
# 108   83.333333
# 109   90.000000
# 110   80.000000
# 111   80.000000
# 112   79.600000
#
# [113 rows x 8 columns]

# %%
def pearson_similarity(a, b):
    return np.dot((a - np.mean(a)), (b - np.mean(b))) / ((np.linalg.norm(a - np.mean(a))) * (np.linalg.norm(b - np.mean(b))))

# %%
target_index = 1
pearson_result = []
target_numpy = group_train_data.iloc[target_index].to_numpy()[1:]

for index, row in group_train_data.iterrows():
    if index == target_index:
        continue
    index_numpy = row.to_numpy()[1:]
    pearson_result.append((index, pearson_similarity(target_numpy, index_numpy)))

pearson_result = sorted(pearson_result, key=lambda x:x[1], reverse=True)
print(pearson_result)
# Out:
# [(11, 0.9998121325760507), (84, 0.9966275484315577), (103, 0.9960679259944566), (90, 0.9921783834503103), (38, 0.9913432466198084), (82, 0.9905114423773487), (62, 0.9902994191173596), (60, 0.9892002695398717), (111, 0.9872492171332885), (93, 0.9871464605950776), (15, 0.9864354534277264), (12, 0.9862260210814087), (85, 0.9852511480887011), (35, 0.9846752188752151), (72, 0.9842728091442136), (43, 0.9836093317486827), (47, 0.9836093317486827), (52, 0.98327087339687), (53, 0.9824445696199576), (99, 0.9822317191452244), (51, 0.9821989672340616), (13, 0.9818396299917825), (83, 0.9817654706789745), (88, 0.9802345172322854), (46, 0.979422445281545), (75, 0.9793774357707542), (30, 0.9785795145876778), (4, 0.9769138522216371), (104, 0.9768637526658606), (7, 0.9756781945582691), (80, 0.9755379011727313), (5, 0.9739358025964591), (73, 0.9730303740438072), (66, 0.9722154958026643), (63, 0.9721186646151736), (40, 0.9719852750158784), (24, 0.9709964130993073), (101, 0.9695022270935898), (91, 0.9680883245008602), (87, 0.9674758333983217), (97, 0.9670214182852904), (56, 0.966785244029749), (16, 0.9666022329883968), (31, 0.9657344032629812), (42, 0.9654410397235567), (94, 0.9653051969737586), (78, 0.9649686201668556), (3, 0.9643947519184537), (112, 0.9636447528709146), (89, 0.9634546666265255), (48, 0.9629915185553284), (17, 0.962588600159955), (39, 0.9625506160194919), (44, 0.9586520919638903), (70, 0.9575743884893481), (9, 0.9535655989912648), (108, 0.9527583871719673), (22, 0.9526628772814457), (34, 0.9513888267469476), (92, 0.9487206946003841), (110, 0.9438275552912749), (76, 0.942581444704263), (6, 0.9425794713982758), (102, 0.9411069891741831), (79, 0.9384124711049344), (59, 0.9302999826949623), (86, 0.9248713633108178), (64, 0.9241321817963598), (25, 0.9223760677918447), (10, 0.9128649536342334), (50, 0.9103246424724434), (28, 0.9027895857443785), (19, 0.9015926108041156), (21, 0.9009337986848126), (27, 0.8990745131459074), (61, 0.8947297986810727), (18, 0.8840737462524619), (29, 0.8840737462524619), (98, 0.8821552430067009), (71, 0.8811403853771255), (0, 0.8801271162123887), (36, 0.877207625466279), (74, 0.875638854844582), (41, 0.8644118488634254), (81, 0.8441486882049178), (67, 0.8362918494249126), (49, 0.8327976005703386), (33, 0.8321716566506825), (65, 0.8050675197168857), (32, 0.7994847205067579), (100, 0.7811874880502673), (45, 0.780060063952506), (37, 0.7733043699715019), (2, 0.7637153668780909), (8, 0.7548026717699327), (54, 0.7480679360393678), (105, 0.733427631662326), (14, 0.7263335294102687), (69, 0.6890958291773914), (68, 0.6834375973613166), (96, 0.6759069215416812), (20, 0.6425771515652934), (77, 0.6425771515652934), (55, 0.6340926398151027), (26, 0.6269885868294593), (58, 0.6112491479086938), (109, 0.5872606814105835), (23, 0.5807507347955123), (95, 0.516050197390289), (107, 0.2895039590686169), (57, 0.26548834214541717), (106, 0.24329040052500434)]

# %%
grouped_train_data
# Out:
#                                                          BEFORE_AGTRON  \
# GROWING_REGION       TREE_VARIETY          ROAST_LEVEL
# region_africa_arabia tree_variety_bourbon  Light             64.375000
#                                            Medium            49.333333
#                                            Medium-Dark       44.000000
#                                            Medium-Light      56.740741
#                      tree_variety_catuai   Medium-Light      56.666667
# ...                                                                ...
# region_south_america tree_variety_pacamara Medium-Light      58.000000
#                      tree_variety_robusta  Medium-Light      54.000000
#                      tree_variety_typica   Light             59.500000
#                                            Medium            49.500000
#                                            Medium-Light      56.240000
#
#                                                          AFTER_AGTRON  \
# GROWING_REGION       TREE_VARIETY          ROAST_LEVEL
# region_africa_arabia tree_variety_bourbon  Light            82.125000
#                                            Medium           65.166667
#                                            Medium-Dark      52.666667
#                                            Medium-Light     75.518519
#                      tree_variety_catuai   Medium-Light     72.666667
# ...                                                               ...
# region_south_america tree_variety_pacamara Medium-Light     78.000000
#                      tree_variety_robusta  Medium-Light     72.000000
#                      tree_variety_typica   Light            77.000000
#                                            Medium           66.000000
#                                            Medium-Light     74.960000
#
#                                                             AROMA  \
# GROWING_REGION       TREE_VARIETY          ROAST_LEVEL
# region_africa_arabia tree_variety_bourbon  Light         9.000000
#                                            Medium        8.666667
#                                            Medium-Dark   8.333333
#                                            Medium-Light  8.759259
#                      tree_variety_catuai   Medium-Light  8.333333
# ...                                                           ...
# region_south_america tree_variety_pacamara Medium-Light  8.666667
#                      tree_variety_robusta  Medium-Light  9.000000
#                      tree_variety_typica   Light         9.000000
#                                            Medium        8.500000
#                                            Medium-Light  8.920000
#
#                                                          ACIDITY/STRUCTURE  \
# GROWING_REGION       TREE_VARIETY          ROAST_LEVEL
# region_africa_arabia tree_variety_bourbon  Light                  8.250000
#                                            Medium                 8.500000
#                                            Medium-Dark            5.000000
#                                            Medium-Light           8.375000
#                      tree_variety_catuai   Medium-Light           8.000000
# ...                                                                    ...
# region_south_america tree_variety_pacamara Medium-Light           8.500000
#                      tree_variety_robusta  Medium-Light           5.000000
#                      tree_variety_typica   Light                  8.500000
#                                            Medium                 8.000000
#                                            Medium-Light           8.347826
#
#                                                              BODY    FLAVOR  \
# GROWING_REGION       TREE_VARIETY          ROAST_LEVEL
# region_africa_arabia tree_variety_bourbon  Light         8.750000  9.000000
#                                            Medium        8.333333  9.000000
#                                            Medium-Dark   8.000000  8.333333
#                                            Medium-Light  8.611111  8.925926
#                      tree_variety_catuai   Medium-Light  8.333333  8.666667
# ...                                                           ...       ...
# region_south_america tree_variety_pacamara Medium-Light  9.000000  9.000000
#                      tree_variety_robusta  Medium-Light  9.000000  9.000000
#                      tree_variety_typica   Light         9.000000  9.000000
#                                            Medium        8.500000  9.000000
#                                            Medium-Light  8.520000  9.000000
#
#                                                          AFTERTASTE
# GROWING_REGION       TREE_VARIETY          ROAST_LEVEL
# region_africa_arabia tree_variety_bourbon  Light           8.000000
#                                            Medium          8.333333
#                                            Medium-Dark     8.000000
#                                            Medium-Light    8.000000
#                      tree_variety_catuai   Medium-Light    8.000000
# ...                                                             ...
# region_south_america tree_variety_pacamara Medium-Light    8.333333
#                      tree_variety_robusta  Medium-Light    9.000000
#                      tree_variety_typica   Light           8.000000
#                                            Medium          8.000000
#                                            Medium-Light    7.960000
#
# [113 rows x 7 columns]
